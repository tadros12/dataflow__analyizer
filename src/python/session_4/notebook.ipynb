# %%
import os

path = "/workspaces/dataflow__analyizer/src/python/session_4"

print(path)
# Out:
# /workspaces/dataflow__analyizer/src/python/session_4

# %%
file = os.listdir(path)
print(file)
# Out:
# ['testfile.txt', 'notebook.ipynb']

# %%
import os 

directory = "./tmp"


if not os.path.exists(directory):
    os.makedirs(directory)
else:
    print("folder already exix")

# %%
for i in range (20):
    inner_path = os.path.join(path,"dir"+str(i))
    if not os.path.exists(inner_path):
        os.makedirs(inner_path)

# %%
from create_folders import create_folder

path = "tmp3"
create_folder(path)

# %% [markdown]
# # files

# %%
with open("./tmp/text" , "a+") as file:
    file.write("new line added\n")
    file.seek(0)

# %%
try:
    x = 10
    y = int(input())
    x/y

except:
    print("division by zero")
# Out:
# division by zero

# %%
try:
    5/0
except Exception as e:
    print(e)
# Out:
# division by zero
