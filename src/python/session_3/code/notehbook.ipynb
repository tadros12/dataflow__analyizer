# %% [markdown]
# # session 3

# %%
is_sunny = True
temp = 25

if is_sunny :
    print("its sunny day")

    if temp>20:
        print("the weather is warm ")

    else :
        print("the weather is cool")

else :
    print("its not a sunny day")
# Out:
# its sunny day
# the weather is warm

# %%
invaild  = True

while(invaild):
    student_grade = int(input("enter grade"))
    if student_grade> 100 or student_grade<70:
        invaild = True        
    else :
        print(student_grade)
        invaild = False
# Out:
# 90

# %%
for i in range(6):
    if i == 3:
        continue
    print(i)


for i in range (6):
    
    if i == 4:
        break
    print(i)
# Out:
# 0
# 1
# 2
# 4
# 5
# 0
# 1
# 2
# 3

# %%
from user_info import info_user

# %%
# def info_user(name,age):
#     """
#         param_1 : take the name from user 
#         type param_1 : str
#         param_2: take age from the user
#         type param_2 :int


#         return :return string of the name and age
#         type return : str
#     """
#     return f"my name is {name } , my age is {age}"

print(info_user("tad",21))
# Out:
# my name is tad , my age is 21

# %%
def func (item , lst = []):
    lst.append(item)
    return lst

print(func("1"))

print(func("2"))

print(func("3"))
# Out:
# ['1']
# ['1', '2']
# ['1', '2', '3']

# %%
def function_1(name, age):
    print(f"my name is {name } , age is {age}")

function_1("amit" , 40)
# Out:
# my name is amit , age is 40

# %%
function_1(age=40,name="amit")
# Out:
# my name is amit , age is 40

# %% [markdown]
# # varadic aargument

# %%
def function_varadic(*name):
    print(name)
    print(type(name))


function_varadic("tad","eating" , "eating")
# Out:
# ('tad', 'eating', 'eating')
# <class 'tuple'>

# %%
def funciton_kwrgs(**name):
    print(name)
    print(type(name))


funciton_kwrgs(key1 =10.5 , key2 =2 , key3 = "machine learning" , key4 = "python")
# Out:
# {'key1': 10.5, 'key2': 2, 'key3': 'machine learning', 'key4': 'python'}
# <class 'dict'>

# %% [markdown]
# # lambda function

# %%
function_name =lambda x:x+10
function_name(5)
# Out:
# 15
