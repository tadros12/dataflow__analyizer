# %%
list_one = [1,2,3,4,"depi" , "learning", True , [1,2,3,4, "true"] , ["ML","DL" , "DS"]]
print(f"{list_one} and with type of {type(list_one)}")
# Out:
# [1, 2, 3, 4, 'depi', 'learning', True, [1, 2, 3, 4, 'true'], ['ML', 'DL', 'DS']] and with type of <class 'list'>

# %%
list_one[7][4][0]
