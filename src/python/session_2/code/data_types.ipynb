# %%
list_one = [1,2,3,4,"depi" , "learning", True , [1,2,3,4, "true"] , ["ML","DL" , "DS"]]
print(f"{list_one} , {type(list_one)}")
# Out:
# [1, 2, 3, 4, 'depi', 'learning', True, [1, 2, 3, 4, 'true'], ['ML', 'DL', 'DS']] , <class 'list'>

# %%
list_one[7][4][1]
# Out:
# 'r'

# %%
list_2 = ["depi" , "learning" , "python"]
list_2.append(5)
list_2
# Out:
# ['depi', 'learning', 'python', 5]

# %%
list_2.insert(0,"amit")
list_2
# Out:
# ['amit', 'depi', 'learning', 'python', 5]

# %%
list_1 = [1,2,3]
list_2 = [4,5,6]

list_1.extend(list_2)
list_1
# Out:
# [1, 2, 3, 4, 5, 6]

# %%
list_1.remove(1)
list_1
# Out:
# [2, 3, 4, 5, 6]

# %%
item=list_1.pop()
list_1,item
# Out:
# ([2, 3, 4, 5], 6)

# %%
del list_1[0]
list_1
# Out:
# [3, 4, 5]

# %%
print("item")
item = input()


print("removing item : " ,item)
list = ["amit" ,"learning","third"]

list.remove(item)
print(list)
# Out:
# item
# remmoing item :  idk
# ['amit', 'learning']

# %%
list_1.count(5)
# Out:
# 1

# %%
num_1 = float(input( "enter num"))
num_2 = float(input("enter num2"))

print("summation",num_1+num_2)
print("subs",num_1-num_2)
print("multip",num_1*num_2)
print("divation",num_1/num_2)
