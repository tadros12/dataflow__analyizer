# %%
print("hello")
# Out:
# hello

# %%
name = "tad"

age = 21
print("My name is {0} and I am {1} years old.".format(name , age))
print(f"myname is {name} , age is {age}")
# Out:
# My name is tad and I am 21 years old.
# myname is tad , age is 21

# %%
name  = "Depi"
name.upper()
# Out:
# 'DEPI'

# %%
name.lower()
# Out:
# 'depi'

# %%
sentence = 'some sentence i dont know'
sentence_split = sentence.split()
sentence_split
# Out:
# ['some', 'sentence', 'i', 'dont', 'know']

# %%
sent_join = ' '.join(sentence_split)
sent_join
# Out:
# 'some sentence i dont know'

# %%
my_string = "0123456789"
print(my_string[-2:-6:-2])
# Out:
# 86
